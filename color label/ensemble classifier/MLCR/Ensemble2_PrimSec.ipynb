# %%
#Ensemble Ratio CL1 PrimSec
from sklearn.metrics import confusion_matrix,classification_report
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data_binary = pd.read_csv('CL1_BPS_2.csv')
acc_binary = pd.read_csv('testCM_CL1_primsec_Xception_Binary_Result2_report.csv')
data_multi = pd.read_excel('test_all_prim_multiclass.xlsx', sheet_name='Sheet7')
#print(data_multi)
acc_multi = pd.read_csv('testCM_CL1_primsec_multi_xception_report.csv')
#print('Acc_multi',acc_multi)

id_image = pd.DataFrame(data_binary, columns= ['id','Class'])
#print(id_image)
pred1 = pd.DataFrame(data_binary, columns= ['Predicted'])
#print(pred1)
pred2 = pd.DataFrame(data_multi, columns= ['Predicted'])
#print(pred2)
acc_bin = pd.DataFrame(acc_binary.iloc[:, [0,3]])
acc_bin.columns = ['Color', 'Recall']
#print(acc_bin)
acc_mul = pd.DataFrame(acc_multi.iloc[:, [0,3]])
acc_mul.columns = ['Color', 'Recall']
#print(acc_mul)

ratio_Green = acc_bin[acc_bin['Color'] == 'Green'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Green'].iloc[0,1]
ratio_GreenRed = acc_bin[acc_bin['Color'] == 'GreenRed'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'GreenRed'].iloc[0,1]
ratio_GreenYellow = acc_bin[acc_bin['Color'] == 'GreenYellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'GreenYellow'].iloc[0,1]
ratio_Purple = acc_bin[acc_bin['Color'] == 'Purple'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Purple'].iloc[0,1]
ratio_PurpleYellow = acc_bin[acc_bin['Color'] == 'PurpleYellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'PurpleYellow'].iloc[0,1]
ratio_Red = acc_bin[acc_bin['Color'] == 'Red'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Red'].iloc[0,1]
ratio_RedYellow = acc_bin[acc_bin['Color'] == 'RedYellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'RedYellow'].iloc[0,1]
ratio_Yellow = acc_bin[acc_bin['Color'] == 'Yellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Yellow'].iloc[0,1]
ratio = {'Color': ['Green','GreenRed','GreenYellow','Purple','PurpleYellow','Red','RedYellow','Yellow'],
            'Ratio': [ratio_Green, ratio_GreenRed, ratio_GreenYellow, ratio_Purple, ratio_PurpleYellow, ratio_Red, ratio_RedYellow, ratio_Yellow]
            }
ratio_BCMC = pd.DataFrame(ratio, columns = ['Color', 'Ratio'])

def Ensemble(x, predbccolor, predmccolor):
    r1 = ratio_BCMC[ratio_BCMC['Color']==predbccolor].iloc[0,1]
    r2 = 1 / (ratio_BCMC[ratio_BCMC['Color']==predmccolor].iloc[0,1])
    
    if (predbccolor == predmccolor): 
        color = predbccolor
    else:
        if (r1 < r2):
            color = predmccolor
        else:
            color = predbccolor
    return color

predictor1,id1,class1,pred_1,pred_2 = [], [], [], [], []
for index,row in pred1.iterrows():
    print(index)
    colors = []
    vals = []
    color = Ensemble(index, pred1.loc[index][0], pred2.loc[index][0])
    colors.append(color)
    print("Predicted Colors1=",colors)
    
    pred_1.extend([pred1.loc[index][0]])
    pred_2.extend([pred2.loc[index][0]])
    predictor1.extend(list(colors))
    id1.extend([id_image.loc[index][0]])
    class1.extend([id_image.loc[index][1]])

final1 = pd.DataFrame()
final1["id"] = id1
final1["Class"] = class1
final1["Binary_Predicted"] = pred_1
final1["Multiclass_Predicted"] = pred_2
final1["Ensemble_Predicted"] = predictor1
final1.to_csv("CL1_primsec_ensemble3.csv", index=False)

# %%
#Ensemble Ratio CL2 PrimSec
from sklearn.metrics import confusion_matrix,classification_report
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data_binary = pd.read_csv('CL2_BPS_2.csv')
acc_binary = pd.read_csv('testCM_CL2_primsec_Xception_Binary_Result2_report.csv')
data_multi = pd.read_excel('test_all_prim_multiclass.xlsx', sheet_name='Sheet8')
#print(data_multi)
acc_multi = pd.read_csv('testCM_CL2_primsec_multi_xception_report.csv')
#print('Acc_multi',acc_multi)

id_image = pd.DataFrame(data_binary, columns= ['id','Class'])
#print(id_image)
pred1 = pd.DataFrame(data_binary, columns= ['Predicted'])
#print(pred1)
pred2 = pd.DataFrame(data_multi, columns= ['Predicted'])
#print(pred2)
acc_bin = pd.DataFrame(acc_binary.iloc[:, [0,3]])
acc_bin.columns = ['Color', 'Recall']
#print(acc_bin)
acc_mul = pd.DataFrame(acc_multi.iloc[:, [0,3]])
acc_mul.columns = ['Color', 'Recall']
#print(acc_mul)

ratio_Green = acc_bin[acc_bin['Color'] == 'Green'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Green'].iloc[0,1]
ratio_GreenRed = acc_bin[acc_bin['Color'] == 'GreenRed'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'GreenRed'].iloc[0,1]
ratio_GreenWhite = acc_bin[acc_bin['Color'] == 'GreenWhite'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'GreenWhite'].iloc[0,1]
ratio_Purple = acc_bin[acc_bin['Color'] == 'Purple'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Purple'].iloc[0,1]
ratio_PurpleWhite = acc_bin[acc_bin['Color'] == 'PurpleWhite'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'PurpleWhite'].iloc[0,1]
ratio_PurpleYellow = acc_bin[acc_bin['Color'] == 'PurpleYellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'PurpleYellow'].iloc[0,1]
ratio_RedYellow = acc_bin[acc_bin['Color'] == 'RedYellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'RedYellow'].iloc[0,1]
ratio_White = acc_bin[acc_bin['Color'] == 'White'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'White'].iloc[0,1]
ratio_WhiteYellow = acc_bin[acc_bin['Color'] == 'WhiteYellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'WhiteYellow'].iloc[0,1]
ratio_Yellow = acc_bin[acc_bin['Color'] == 'Yellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Yellow'].iloc[0,1]
ratio = {'Color': ['Green','GreenRed','GreenWhite','Purple','PurpleWhite','PurpleYellow','RedYellow','White','WhiteYellow','Yellow'],
            'Ratio': [ratio_Green, ratio_GreenRed, ratio_GreenWhite, ratio_Purple, ratio_PurpleWhite, ratio_PurpleYellow, ratio_RedYellow, ratio_White, ratio_WhiteYellow, ratio_Yellow]
            }
ratio_BCMC = pd.DataFrame(ratio, columns = ['Color', 'Ratio'])

def Ensemble(x, predbccolor, predmccolor):
    r1 = ratio_BCMC[ratio_BCMC['Color']==predbccolor].iloc[0,1]
    r2 = 1 / (ratio_BCMC[ratio_BCMC['Color']==predmccolor].iloc[0,1])
    
    if (predbccolor == predmccolor): 
        color = predbccolor
    else:
        if (r1 < r2):
            color = predmccolor
        else:
            color = predbccolor
    return color

predictor1,id1,class1,pred_1,pred_2 = [], [], [], [], []
for index,row in pred1.iterrows():
    print(index)
    colors = []
    vals = []
    color = Ensemble(index, pred1.loc[index][0], pred2.loc[index][0])
    colors.append(color)
    print("Predicted Colors1=",colors)
    
    pred_1.extend([pred1.loc[index][0]])
    pred_2.extend([pred2.loc[index][0]])
    predictor1.extend(list(colors))
    id1.extend([id_image.loc[index][0]])
    class1.extend([id_image.loc[index][1]])

final1 = pd.DataFrame()
final1["id"] = id1
final1["Class"] = class1
final1["Binary_Predicted"] = pred_1
final1["Multiclass_Predicted"] = pred_2
final1["Ensemble_Predicted"] = predictor1
final1.to_csv("CL2_primsec_ensemble3.csv", index=False)

# %%
#Ensemble Ratio CF1 PrimSec
from sklearn.metrics import confusion_matrix,classification_report
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data_binary = pd.read_csv('CF1_BPS_2.csv')
acc_binary = pd.read_csv('testCM_CF1_primsec_Xception_Binary_Result2_report.csv')
data_multi = pd.read_excel('test_all_prim_multiclass.xlsx', sheet_name='Sheet5')
#print(data_multi)
acc_multi = pd.read_csv('testCM_CF1_primsec_multi_xception_report.csv')
#print('Acc_multi',acc_multi)

id_image = pd.DataFrame(data_binary, columns= ['id','Class'])
#print(id_image)
pred1 = pd.DataFrame(data_binary, columns= ['Predicted'])
#print(pred1)
pred2 = pd.DataFrame(data_multi, columns= ['Predicted'])
#print(pred2)
acc_bin = pd.DataFrame(acc_binary.iloc[:, [0,3]])
acc_bin.columns = ['Color', 'Recall']
#print(acc_bin)
acc_mul = pd.DataFrame(acc_multi.iloc[:, [0,3]])
acc_mul.columns = ['Color', 'Recall']
#print(acc_mul)

ratio_Green = acc_bin[acc_bin['Color'] == 'Green'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Green'].iloc[0,1]
ratio_GreenRed = acc_bin[acc_bin['Color'] == 'GreenRed'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'GreenRed'].iloc[0,1]
ratio_GreenYellow = acc_bin[acc_bin['Color'] == 'GreenYellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'GreenYellow'].iloc[0,1]
ratio_Purple = acc_bin[acc_bin['Color'] == 'Purple'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Purple'].iloc[0,1]
ratio_PurpleYellow = acc_bin[acc_bin['Color'] == 'PurpleYellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'PurpleYellow'].iloc[0,1]
ratio_Red = acc_bin[acc_bin['Color'] == 'Red'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Red'].iloc[0,1]
ratio_RedYellow = acc_bin[acc_bin['Color'] == 'RedYellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'RedYellow'].iloc[0,1]
ratio_Yellow = acc_bin[acc_bin['Color'] == 'Yellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Yellow'].iloc[0,1]
ratio = {'Color': ['Green','GreenRed','GreenYellow','Purple','PurpleYellow','Red','RedYellow','Yellow'],
            'Ratio': [ratio_Green, ratio_GreenRed, ratio_GreenYellow, ratio_Purple, ratio_PurpleYellow, ratio_Red, ratio_RedYellow, ratio_Yellow]
            }
ratio_BCMC = pd.DataFrame(ratio, columns = ['Color', 'Ratio'])

def Ensemble(x, predbccolor, predmccolor):
    r1 = ratio_BCMC[ratio_BCMC['Color']==predbccolor].iloc[0,1]
    r2 = 1 / (ratio_BCMC[ratio_BCMC['Color']==predmccolor].iloc[0,1])
    
    if (predbccolor == predmccolor): 
        color = predbccolor
    else:
        if (r1 < r2):
            color = predmccolor
        else:
            color = predbccolor
    return color

predictor1,id1,class1,pred_1,pred_2 = [], [], [], [], []
for index,row in pred1.iterrows():
    print(index)
    colors = []
    vals = []
    color = Ensemble(index, pred1.loc[index][0], pred2.loc[index][0])
    colors.append(color)
    print("Predicted Colors1=",colors)
    
    pred_1.extend([pred1.loc[index][0]])
    pred_2.extend([pred2.loc[index][0]])
    predictor1.extend(list(colors))
    id1.extend([id_image.loc[index][0]])
    class1.extend([id_image.loc[index][1]])

final1 = pd.DataFrame()
final1["id"] = id1
final1["Class"] = class1
final1["Binary_Predicted"] = pred_1
final1["Multiclass_Predicted"] = pred_2
final1["Ensemble_Predicted"] = predictor1
final1.to_csv("CF1_primsec_ensemble3.csv", index=False)

# %%
#Ensemble Ratio CF2 PrimSec
from sklearn.metrics import confusion_matrix,classification_report
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data_binary = pd.read_csv('CF2_BPS_2.csv')
acc_binary = pd.read_csv('testCM_CF2_primsec_Xception_Binary_Result2_report.csv')
data_multi = pd.read_excel('test_all_prim_multiclass.xlsx', sheet_name='Sheet6')
#print(data_multi)
acc_multi = pd.read_csv('testCM_CF2_primsec_multi_xception_report.csv')
#print('Acc_multi',acc_multi)

id_image = pd.DataFrame(data_binary, columns= ['id','Class'])
#print(id_image)
pred1 = pd.DataFrame(data_binary, columns= ['Predicted'])
#print(pred1)
pred2 = pd.DataFrame(data_multi, columns= ['Predicted'])
#print(pred2)
acc_bin = pd.DataFrame(acc_binary.iloc[:, [0,3]])
acc_bin.columns = ['Color', 'Recall']
#print(acc_bin)
acc_mul = pd.DataFrame(acc_multi.iloc[:, [0,3]])
acc_mul.columns = ['Color', 'Recall']
#print(acc_mul)

ratio_Green = acc_bin[acc_bin['Color'] == 'Green'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Green'].iloc[0,1]
ratio_GreenRed = acc_bin[acc_bin['Color'] == 'GreenRed'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'GreenRed'].iloc[0,1]
ratio_GreenWhite = acc_bin[acc_bin['Color'] == 'GreenWhite'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'GreenWhite'].iloc[0,1]
ratio_GreenYellow = acc_bin[acc_bin['Color'] == 'GreenYellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'GreenYellow'].iloc[0,1]
ratio_Purple = acc_bin[acc_bin['Color'] == 'Purple'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Purple'].iloc[0,1]
ratio_PurpleWhite = acc_bin[acc_bin['Color'] == 'PurpleWhite'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'PurpleWhite'].iloc[0,1]
ratio_Red = acc_bin[acc_bin['Color'] == 'Red'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Red'].iloc[0,1]
ratio_RedYellow = acc_bin[acc_bin['Color'] == 'RedYellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'RedYellow'].iloc[0,1]
ratio_White = acc_bin[acc_bin['Color'] == 'White'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'White'].iloc[0,1]
ratio_Yellow = acc_bin[acc_bin['Color'] == 'Yellow'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'Yellow'].iloc[0,1]
ratio_YellowPurple = acc_bin[acc_bin['Color'] == 'YellowPurple'].iloc[0,1]/acc_mul[acc_mul['Color'] == 'YellowPurple'].iloc[0,1]
ratio = {'Color': ['Green','GreenRed','GreenWhite','GreenYellow','Purple','PurpleWhite','Red','RedYellow','White','Yellow','YellowPurple'],
            'Ratio': [ratio_Green, ratio_GreenRed, ratio_GreenWhite, ratio_GreenYellow, ratio_Purple, ratio_PurpleWhite, ratio_Red, ratio_RedYellow, ratio_White, ratio_Yellow, ratio_YellowPurple]
            }
ratio_BCMC = pd.DataFrame(ratio, columns = ['Color', 'Ratio'])

def Ensemble(x, predbccolor, predmccolor):
    r1 = ratio_BCMC[ratio_BCMC['Color']==predbccolor].iloc[0,1]
    r2 = 1 / (ratio_BCMC[ratio_BCMC['Color']==predmccolor].iloc[0,1])
    
    if (predbccolor == predmccolor): 
        color = predbccolor
    else:
        if (r1 < r2):
            color = predmccolor
        else:
            color = predbccolor
    return color

predictor1,id1,class1,pred_1,pred_2 = [], [], [], [], []
for index,row in pred1.iterrows():
    print(index)
    colors = []
    vals = []
    color = Ensemble(index, pred1.loc[index][0], pred2.loc[index][0])
    colors.append(color)
    print("Predicted Colors1=",colors)
    
    pred_1.extend([pred1.loc[index][0]])
    pred_2.extend([pred2.loc[index][0]])
    predictor1.extend(list(colors))
    id1.extend([id_image.loc[index][0]])
    class1.extend([id_image.loc[index][1]])

final1 = pd.DataFrame()
final1["id"] = id1
final1["Class"] = class1
final1["Binary_Predicted"] = pred_1
final1["Multiclass_Predicted"] = pred_2
final1["Ensemble_Predicted"] = predictor1
final1.to_csv("CF2_primsec_ensemble3.csv", index=False)
