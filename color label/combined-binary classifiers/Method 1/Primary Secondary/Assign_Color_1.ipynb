# %%
#CL1 binary primary secondary
from sklearn.metrics import confusion_matrix,classification_report
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_excel('test_CL1_primsec_binary_xception.xlsx', sheet_name='Sheet1')

id_image = pd.DataFrame(data, columns= ['CL1_PrimSec','Class'])
print(id_image)
pred = pd.DataFrame(data, columns= ['Predicted_Green','Predicted_GreenRed','Predicted_GreenYellow','Predicted_Purple','Predicted_PurpleYellow','Predicted_Red','Predicted_RedYellow'])
print(pred)
val = pd.DataFrame(data, columns= ['Softmax_Green','Softmax_GreenRed','Softmax_GreenYellow','Softmax_Purple','Softmax_PurpleYellow','Softmax_Red','Softmax_RedYellow'])
print(val)

predictor1,predictor2,id1,id2,class1,class2 = [], [], [], [], [], []
for index,row in pred.iterrows():
    print(index)
    colors = []
    vals = []
    if pred.loc[index][0]=='Green':
        color = "Green"
        colors.append(color)
        valss = val.iloc[index,0]
        vals.append(valss)
    if pred.loc[index][1]=='GreenRed':
        color = "GreenRed"
        colors.append(color)
        valss = val.iloc[index,1]
        vals.append(valss)
    if pred.loc[index][2]=='GreenYellow':
        color = "GreenYellow"
        colors.append(color)
        valss = val.iloc[index,2]
        vals.append(valss)
    if pred.loc[index][3]=='Purple':
        color = "Purple"
        colors.append(color)
        valss = val.iloc[index,3]
        vals.append(valss)
    if pred.loc[index][4]=='PurpleYellow':
        color = "PurpleYellow"
        colors.append(color)
        valss = val.iloc[index,4]
        vals.append(valss)
    if pred.loc[index][5]=='Red':
        color = "Red"
        colors.append(color)
        valss = val.iloc[index,5]
        vals.append(valss)
    if pred.loc[index][6]=='RedYellow':
        color = "RedYellow"
        colors.append(color)
        valss = val.iloc[index,6]
        vals.append(valss)
    if pred.loc[index][0]!='Green' and pred.loc[index][1]!='GreenRed' and pred.loc[index][2]!='GreenYellow' and pred.loc[index][3]!='Purple' and pred.loc[index][4]!='PurpleYellow' and pred.loc[index][5]!='Red' and pred.loc[index][6]!='RedYellow':
        colors = ["Yellow"]
    
    col = colors
    
    if len(colors)>1:
        colors = ["Inconsistent"]

    print("Predicted Colors1=",colors)
    
    predictor1.extend(list(colors))
    id1.extend([id_image.loc[index][0]])
    class1.extend([id_image.loc[index][1]])

final1 = pd.DataFrame()
final1["id"] = id1
final1["Class"] = class1
final1["Predicted"] = predictor1
final1.to_csv("CL1_BPS_1.csv", index=False)
# Out:
#     CL1_PrimSec         Class
# 0      1000.jpg        Yellow
# 1      1001.jpg        Yellow
# 2      1054.jpg  PurpleYellow
# 3      1055.jpg  PurpleYellow
# 4      1056.jpg  PurpleYellow
# 5      1057.jpg  PurpleYellow
# 6      1058.jpg  PurpleYellow
# 7      1059.jpg  PurpleYellow
# 8      1060.jpg  PurpleYellow
# 9      1085.jpg        Yellow
# 10     1086.jpg        Yellow
# 11     1087.jpg        Yellow
# 12     1185.jpg     RedYellow
# 13     1186.jpg     RedYellow
# 14     1187.jpg     RedYellow
# 15     1188.jpg     RedYellow
# 16     1189.jpg     RedYellow
# 17     1190.jpg     RedYellow
# 18     1191.jpg     RedYellow
# 19     1192.jpg     RedYellow
# 20     1193.jpg     RedYellow
# 21     1194.jpg     RedYellow
# 22     1195.jpg     RedYellow
# 23     1322.jpg        Yellow
# 24     1323.jpg        Yellow
# 25     1324.jpg        Yellow
# 26     1325.jpg        Yellow
# 27     1326.jpg        Yellow
# 28     1327.jpg        Yellow
# 29     1385.jpg        Yellow
# ...

# %%
#CL2 binary primary secondary
from sklearn.metrics import confusion_matrix,classification_report
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_excel('test_CL2_primsec_binary_xception.xlsx', sheet_name='Sheet1')

id_image = pd.DataFrame(data, columns= ['CL2_PrimSec','Class'])
print(id_image)
pred = pd.DataFrame(data, columns= ['Predicted_Green','Predicted_GreenRed','Predicted_GreenWhite','Predicted_Purple','Predicted_PurpleWhite','Predicted_PurpleYellow','Predicted_RedYellow','Predicted_White','Predicted_WhiteYellow'])
print(pred)
val = pd.DataFrame(data, columns= ['Softmax_Green','Softmax_GreenRed','Softmax_GreenWhite','Softmax_Purple','Softmax_PurpleWhite','Softmax_PurpleYellow','Softmax_RedYellow','Softmax_White','Softmax_WhiteYellow'])
print(val)

predictor1,predictor2,id1,id2,class1,class2 = [], [], [], [], [], []
for index,row in pred.iterrows():
    print(index)
    print(row)
    colors = []
    vals = []
    if pred.loc[index][0]=='Green':
        color = "Green"
        colors.append(color)
        valss = val.iloc[index,0]
        vals.append(valss)
    if pred.loc[index][1]=='GreenRed':
        color = "GreenRed"
        colors.append(color)
        valss = val.iloc[index,1]
        vals.append(valss)
    if pred.loc[index][2]=='GreenWhite':
        color = "GreenWhite"
        colors.append(color)
        valss = val.iloc[index,2]
        vals.append(valss)
    if pred.loc[index][3]=='Purple':
        color = "Purple"
        colors.append(color)
        valss = val.iloc[index,3]
        vals.append(valss)
    if pred.loc[index][4]=='PurpleWhite':
        color = "PurpleWhite"
        colors.append(color)
        valss = val.iloc[index,4]
        vals.append(valss)
    if pred.loc[index][5]=='PurpleYellow':
        color = "PurpleYellow"
        colors.append(color)
        valss = val.iloc[index,5]
        vals.append(valss)
    if pred.loc[index][6]=='RedYellow':
        color = "RedYellow"
        colors.append(color)
        valss = val.iloc[index,6]
        vals.append(valss)
    if pred.loc[index][7]=='White':
        color = "White"
        colors.append(color)
        valss = val.iloc[index,7]
        vals.append(valss)
    if pred.loc[index][8]=='WhiteYellow':
        color = "WhiteYellow"
        colors.append(color)
        valss = val.iloc[index,8]
        vals.append(valss)
    if pred.loc[index][0]!='Green' and pred.loc[index][1]!='GreenRed' and pred.loc[index][2]!='GreenWhite' and pred.loc[index][3]!='Purple' and pred.loc[index][4]!='PurpleWhite'and pred.loc[index][5]!='PurpleYellow' and pred.loc[index][6]!='RedYellow' and pred.loc[index][7]!='White' and pred.loc[index][8]!='WhiteYellow':
        colors = ["Yellow"]
    
    col = colors
    
    if len(colors)>1:
        colors = ["Inconsistent"]

    print("Predicted Colors1=",colors)
    
    predictor1.extend(list(colors))
    id1.extend([id_image.loc[index][0]])
    class1.extend([id_image.loc[index][1]])

final1 = pd.DataFrame()
final1["id"] = id1
final1["Class"] = class1
final1["Predicted"] = predictor1
final1.to_csv("CL2_BPS_1.csv", index=False)
# Out:
#     CL2_PrimSec        Class
# 0      1000.jpg        White
# 1      1001.jpg        White
# 2      1054.jpg  PurpleWhite
# 3      1055.jpg  PurpleWhite
# 4      1056.jpg  PurpleWhite
# 5      1057.jpg  PurpleWhite
# 6      1058.jpg  PurpleWhite
# 7      1059.jpg  PurpleWhite
# 8      1060.jpg  PurpleWhite
# 9      1085.jpg        White
# 10     1086.jpg        White
# 11     1087.jpg        White
# 12     1185.jpg    RedYellow
# 13     1186.jpg    RedYellow
# 14     1187.jpg    RedYellow
# 15     1188.jpg    RedYellow
# 16     1189.jpg    RedYellow
# 17     1190.jpg    RedYellow
# 18     1191.jpg    RedYellow
# 19     1192.jpg    RedYellow
# 20     1193.jpg    RedYellow
# 21     1194.jpg    RedYellow
# 22     1195.jpg    RedYellow
# 23     1322.jpg        White
# 24     1323.jpg        White
# 25     1324.jpg        White
# 26     1325.jpg        White
# 27     1326.jpg        White
# 28     1327.jpg        White
# 29     1385.jpg        White
# ..          ...          ...
# ...

# %%
#CF1 binary primary secondary
from sklearn.metrics import confusion_matrix,classification_report
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_excel('test_CF1_primsec_binary_xception.xlsx', sheet_name='Sheet1')

id_image = pd.DataFrame(data, columns= ['CF1_PrimSec','Class'])
print(id_image)
pred = pd.DataFrame(data, columns= ['Predicted_Green','Predicted_GreenRed','Predicted_GreenYellow','Predicted_Purple','Predicted_PurpleYellow','Predicted_Red','Predicted_RedYellow'])
print(pred)
val = pd.DataFrame(data, columns= ['Softmax_Green','Softmax_GreenRed','Softmax_GreenYellow','Softmax_Purple','Softmax_PurpleYellow','Softmax_Red','Softmax_RedYellow'])
print(val)

predictor1,predictor2,id1,id2,class1,class2 = [], [], [], [], [], []
for index,row in pred.iterrows():
    print(index)
    print(row)
    colors = []
    vals = []
    if pred.loc[index][0]=='Green':
        color = "Green"
        colors.append(color)
        valss = val.iloc[index,0]
        vals.append(valss)
    if pred.loc[index][1]=='GreenRed':
        color = "GreenRed"
        colors.append(color)
        valss = val.iloc[index,1]
        vals.append(valss)
    if pred.loc[index][2]=='GreenYellow':
        color = "GreenYellow"
        colors.append(color)
        valss = val.iloc[index,2]
        vals.append(valss)
    if pred.loc[index][3]=='Purple':
        color = "Purple"
        colors.append(color)
        valss = val.iloc[index,3]
        vals.append(valss)
    if pred.loc[index][4]=='PurpleYellow':
        color = "PurpleYellow"
        colors.append(color)
        valss = val.iloc[index,4]
        vals.append(valss)
    if pred.loc[index][5]=='Red':
        color = "Red"
        colors.append(color)
        valss = val.iloc[index,5]
        vals.append(valss)
    if pred.loc[index][6]=='RedYellow':
        color = "RedYellow"
        colors.append(color)
        valss = val.iloc[index,6]
        vals.append(valss)
    if pred.loc[index][0]!='Green' and pred.loc[index][1]!='GreenRed' and pred.loc[index][2]!='GreenYellow' and pred.loc[index][3]!='Purple' and pred.loc[index][4]!='PurpleYellow' and pred.loc[index][5]!='Red' and pred.loc[index][6]!='RedYellow':
        colors = ["Yellow"]
    
    if len(colors)>1:
        colors = ["Inconsistent"]

    print("Predicted Colors1=",colors)
    
    predictor1.extend(list(colors))
    id1.extend([id_image.loc[index][0]])
    class1.extend([id_image.loc[index][1]])

final1 = pd.DataFrame()
final1["id"] = id1
final1["Class"] = class1
final1["Predicted"] = predictor1
final1.to_csv("CF1_BPS_1.csv", index=False)
# Out:
#     CF1_PrimSec         Class
# 0      1000.jpg     RedYellow
# 1      1001.jpg     RedYellow
# 2      1054.jpg  PurpleYellow
# 3      1055.jpg  PurpleYellow
# 4      1056.jpg  PurpleYellow
# 5      1057.jpg  PurpleYellow
# 6      1058.jpg  PurpleYellow
# 7      1059.jpg  PurpleYellow
# 8      1060.jpg  PurpleYellow
# 9      1085.jpg     RedYellow
# 10     1086.jpg     RedYellow
# 11     1087.jpg     RedYellow
# 12     1185.jpg  PurpleYellow
# 13     1186.jpg  PurpleYellow
# 14     1187.jpg  PurpleYellow
# 15     1188.jpg  PurpleYellow
# 16     1189.jpg  PurpleYellow
# 17     1190.jpg  PurpleYellow
# 18     1191.jpg  PurpleYellow
# 19     1192.jpg  PurpleYellow
# 20     1193.jpg  PurpleYellow
# 21     1194.jpg  PurpleYellow
# 22     1195.jpg  PurpleYellow
# 23     1322.jpg         Green
# 24     1323.jpg         Green
# 25     1324.jpg         Green
# 26     1325.jpg         Green
# 27     1326.jpg         Green
# 28     1327.jpg         Green
# 29     1385.jpg     RedYellow
# ...

# %%
#CF2 binary primary secondary
from sklearn.metrics import confusion_matrix,classification_report
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_excel('test_CF2_primsec_binary_xception.xlsx', sheet_name='Sheet1')

id_image = pd.DataFrame(data, columns= ['CF2_PrimSec','Class'])
print(id_image)
pred = pd.DataFrame(data, columns= ['Predicted_Green','Predicted_GreenRed','Predicted_GreenWhite','Predicted_GreenYellow','Predicted_Purple','Predicted_PurpleWhite','Predicted_Red','Predicted_RedYellow','Predicted_White','Predicted_YellowPurple'])
print(pred)
val = pd.DataFrame(data, columns= ['Softmax_Green','Softmax_GreenRed','Softmax_GreenWhite','Softmax_GreenYellow','Softmax_Purple','Softmax_PurpleWhite','Softmax_Red','Softmax_RedYellow','Softmax_White','Softmax_YellowPurple'])
print(val)

predictor1,predictor2,id1,id2,class1,class2 = [], [], [], [], [], []
for index,row in pred.iterrows():
    print(index)
    colors = []
    vals = []
    if pred.loc[index][0]=='Green':
        color = "Green"
        colors.append(color)
        valss = val.iloc[index,0]
        vals.append(valss)
    if pred.loc[index][1]=='GreenRed':
        color = "GreenRed"
        colors.append(color)
        valss = val.iloc[index,1]
        vals.append(valss)
    if pred.loc[index][2]=='GreenWhite':
        color = "GreenWhite"
        colors.append(color)
        valss = val.iloc[index,2]
        vals.append(valss)
    if pred.loc[index][3]=='GreenYellow':
        color = "GreenYellow"
        colors.append(color)
        valss = val.iloc[index,3]
        vals.append(valss)
    if pred.loc[index][4]=='Purple':
        color = "Purple"
        colors.append(color)
        valss = val.iloc[index,4]
        vals.append(valss)
    if pred.loc[index][5]=='PurpleWhite':
        color = "PurpleWhite"
        colors.append(color)
        valss = val.iloc[index,5]
        vals.append(valss)
    if pred.loc[index][6]=='Red':
        color = "Red"
        colors.append(color)
        valss = val.iloc[index,6]
        vals.append(valss)
    if pred.loc[index][7]=='RedYellow':
        color = "RedYellow"
        colors.append(color)
        valss = val.iloc[index,7]
        vals.append(valss)
    if pred.loc[index][8]=='White':
        color = "White"
        colors.append(color)
        valss = val.iloc[index,8]
        vals.append(valss)
    if pred.loc[index][9]=='YellowPurple':
        color = "YellowPurple"
        colors.append(color)
        valss = val.iloc[index,9]
        vals.append(valss)
    if pred.loc[index][0]!='Green' and pred.loc[index][1]!='GreenRed' and pred.loc[index][2]!='GreenWhite' and pred.loc[index][3]!='GreenYellow' and pred.loc[index][4]!='Purple' and pred.loc[index][5]!='PurpleWhite'and pred.loc[index][6]!='Red' and pred.loc[index][7]!='RedYellow' and pred.loc[index][8]!='White' and pred.loc[index][9]!='YellowPurple':
        colors = ["Yellow"]
    
    col = colors
    
    if len(colors)>1:
        colors = ["Inconsistent"]

    print("Predicted Colors1=",colors)
    
    predictor1.extend(list(colors))
    id1.extend([id_image.loc[index][0]])
    class1.extend([id_image.loc[index][1]])

final1 = pd.DataFrame()
final1["id"] = id1
final1["Class"] = class1
final1["Predicted"] = predictor1
final1.to_csv("CF2_BPS_1.csv", index=False)
# Out:
#     CF2_PrimSec         Class
# 0      1000.jpg     RedYellow
# 1      1001.jpg     RedYellow
# 2      1054.jpg  YellowPurple
# 3      1055.jpg  YellowPurple
# 4      1056.jpg  YellowPurple
# 5      1057.jpg  YellowPurple
# 6      1058.jpg  YellowPurple
# 7      1059.jpg  YellowPurple
# 8      1060.jpg  YellowPurple
# 9      1085.jpg     RedYellow
# 10     1086.jpg     RedYellow
# 11     1087.jpg     RedYellow
# 12     1185.jpg  YellowPurple
# 13     1186.jpg  YellowPurple
# 14     1187.jpg  YellowPurple
# 15     1188.jpg  YellowPurple
# 16     1189.jpg  YellowPurple
# 17     1190.jpg  YellowPurple
# 18     1191.jpg  YellowPurple
# 19     1192.jpg  YellowPurple
# 20     1193.jpg  YellowPurple
# 21     1194.jpg  YellowPurple
# 22     1195.jpg  YellowPurple
# 23     1322.jpg         Green
# 24     1323.jpg         Green
# 25     1324.jpg         Green
# 26     1325.jpg         Green
# 27     1326.jpg         Green
# 28     1327.jpg         Green
# 29     1385.jpg     RedYellow
# ...
